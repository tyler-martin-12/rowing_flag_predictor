# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta 
import time
import requests
import pickle

# %%
df = pd.read_csv('tweets.csv',index_col=0)
df.reset_index(drop=True,inplace=True)

# %%
#df

# %%
def str_to_date(string):
    dt = datetime.strptime(string,'%Y-%m-%d %H:%M:%S')
    return dt

# %%
df['datetime'] = df['timestamp'].apply(str_to_date)
df = df.copy().drop('timestamp',axis=1)

# %%
dt = df['datetime'].iloc[300]
new_dt = dt + timedelta(hours = 1)

# %%
start_dt = df['datetime'].iloc[0]

get_weather = []

for hour_idx in range(100000):
    this_dt = start_dt + timedelta(hours = hour_idx)
    
    last_dt, color, time_until_next, time_from_prev = get_flag_color(this_dt)
    #time_until_next < timedelta(days = 3)
    if type(color) == str and time_from_prev < timedelta(days = 2):
        #print(color, time_from_prev, time_until_next)
        get_weather.append([this_dt,color])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-132-4d54ac66a610> in <module>
#       6     this_dt = start_dt + timedelta(hours = hour_idx)
#       7
# ----> 8     last_dt, color, time_until_next, time_from_prev = get_flag_color(this_dt)
#       9     #time_until_next < timedelta(days = 3)
#      10     if type(color) == str and time_from_prev < timedelta(days = 2):
#
# <ipython-input-96-3fe47bf3ab62> in get_flag_color(dt)
#       4     while dt > this_dt:
#       5         idx += 1
# ----> 6         this_dt = df['datetime'].iloc[idx]
#       7     last_dt = df['datetime'].iloc[idx - 1]
#       8     color = df['color'].iloc[idx - 1]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2137         len_axis = len(self.obj._get_axis(axis))
#    2138         if key >= len_axis or key < -len_axis:
# -> 2139             raise IndexError("single positional indexer is out-of-bounds")
#    2140
#    2141     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
last_dt
# Out:
# Timestamp('2017-11-23 17:00:00')

# %%
100000 / 24 / 365
# Out:
# 11.415525114155251

# %%
hour_idx
# Out:
# 67697

# %%
len(get_weather)
# Out:
# 7276

# %%
#with open('get_weather.pkl', 'wb') as handle:
#    pickle.dump(get_weather, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('get_weather.pkl', 'rb') as handle:
    times_and_colors = pickle.load(handle)

# %%
counter = 0

for time,color in enumerate(times_and_colors, start=0):
    if color == 'red':
        counter += 1
print(counter)
# Out:
# 0

# %%
counter = 0

for count, item in enumerate(times_and_colors, start=0):
    time, color = item
    if color == 'yellow':
        print(count)
# Out:
# 0
# 1
# 28
# 29
# 30
# 31
# 32
# 33
# 34
# 35
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 150
# 151
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 294
# 295
# 343
# 344
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# 541
# 542
# 543
# 544
# 545
# 586
# 587
# 588
# 589
# 590
# 591
# 592
# 593
# 594
# 595
# 596
# 597
# 598
# 599
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 680
# 703
# 704
# 705
# 706
# 707
# 708
# 709
# 710
# 711
# 712
# 786
# 787
# 788
# 789
# 790
# 791
# 792
# 793
# 794
# 795
# 796
# 797
# 798
# 799
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# 825
# 826
# 827
# 828
# 829
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 945
# 946
# 947
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1239
# 1240
# 1241
# 1242
# 1290
# 1291
# 1292
# 1293
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1532
# 1533
# 1534
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1542
# 1543
# 1544
# 1545
# 1546
# 1547
# 1548
# 1549
# 1550
# 1551
# 1552
# 1553
# 1554
# 1555
# 1556
# 1557
# 1558
# 1559
# 1560
# 1561
# 1562
# 1563
# 1564
# 1565
# 1603
# 1604
# 1605
# 1606
# 1607
# 1608
# 1609
# 1635
# 1636
# 1637
# 1638
# 1639
# 1810
# 1811
# 1812
# 1813
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# 2051
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# 2211
# 2212
# 2213
# 2214
# 2215
# 2216
# 2217
# 2218
# 2219
# 2220
# 2221
# 2222
# 2223
# 2224
# 2225
# 2226
# 2227
# 2228
# 2229
# 2230
# 2231
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2294
# 2295
# 2296
# 2297
# 2298
# 2299
# 2300
# 2301
# 2302
# 2303
# 2304
# 2305
# 2306
# 2354
# 2355
# 2356
# 2404
# 2405
# 2406
# 2407
# 2408
# 2409
# 2410
# 2411
# 2412
# 2413
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# 2448
# 2449
# 2450
# 2498
# 2499
# 2500
# 2501
# 2549
# 2550
# 2551
# 2552
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# 2559
# 2560
# 2561
# 2562
# 2563
# 2564
# 2565
# 2566
# 2567
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# 2575
# 2576
# 2577
# 2578
# 2579
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# 2589
# 2590
# 2591
# 2592
# 2593
# 2594
# 2595
# 2690
# 2691
# 2692
# 2693
# 2694
# 2695
# 2696
# 2697
# 2698
# 2699
# 2717
# 2718
# 2719
# 2720
# 2721
# 2722
# 2723
# 2724
# 2725
# 2726
# 2727
# 2728
# 2729
# 2730
# 2731
# 2732
# 2780
# 2781
# 2782
# 2783
# 2784
# 2785
# 2786
# 2787
# 2788
# 2789
# 2790
# 2885
# 2886
# 2887
# 2888
# 2889
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3410
# 3411
# 3412
# 3413
# 3414
# 3415
# 3416
# 3417
# 3418
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# 3426
# 3427
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# 3435
# 3436
# 3437
# 3438
# 3439
# 3440
# 3441
# 3442
# 3443
# 3444
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# 3498
# 3499
# 3500
# 3501
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 
# 6397
# 6398
# 6399
# 6400
# 6401
# 6402
# 6415
# 6416
# 6417
# 6418
# 6419
# 6420
# 6421
# 6455
# 6456
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6588
# 6589
# 6590
# 6591
# 6592
# 6640
# 6641
# 6660
# 6661
# 6662
# 6663
# 6664
# 6665
# 6666
# 6667
# 6668
# 6669
# 6670
# 6671
# 6672
# 6673
# 6674
# 6675
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6740
# 6741
# 6742
# 6743
# 6744
# 6745
# 6746
# 6747
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# 6859
# 6860
# 6861
# 6862
# 6863
# 6864
# 6912
# 6913
# 6914
# 6915
# 6916
# 6917
# 6918
# 6919
# 6920
# 6921
# 6922
# 6923
# 6924
# 6925
# 6926
# 6927
# 6928
# 6929
# 6977
# 6978
# 6979
# 6980
# 6981
# 6982
# 6983
# 6984
# 6985
# 6986
# 6987
# 6988
# 6989
# 6990
# 6991
# 6992
# 6993
# 6994
# 6995
# 6996
# 6997
# 6998
# 6999
# 7000
# 7001
# 7002
# 7003
# 7004
# 7005
# 7006
# 7007
# 7008
# 7009
# 7010
# 7011
# 7012
# 7013
# 7014
# 7015
# 7016
# 7017
# 7018
# 7019
# 7020
# 7021
# 7022
# 7023
# 7071
# 7119
# 7120
# 7121
# 7122
# 7123
# 7124
# 7125
# 7126
# 7127
# 7128
# 7129
# 7130
# 7131
# 7132
# 7133
# 7134
# 7135
# 7136
# 7137
# 7185
# 7186
# 7187
# 7188
# 7189
# 7190
# 7191
# 7192
# 7193

# %%
#len(times_and_colors)

# %%
## Dates to weather

# %%
idx = 6758
times_and_colors[idx]
# Out:
# [Timestamp('2017-06-12 07:00:00'), 'yellow']

# %%
this_line = times_and_colors[idx]
weather_dict,weather,unix_time = get_weather_from_dt(this_line)

# %%
weather_dict
# Out:
# {'summary': 'Partly Cloudy',
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 56.43,
#  'windSpeed': 9.21,
#  'visibility': 6.216}

# %%
## Get all weather

# %%
this_line
# Out:
# [Timestamp('2017-06-12 07:00:00'), 'yellow']

# %%
for count, item in enumerate(times_and_colors, start=0):
    if count > 5:
        break
    print(count,item)
# Out:
# 0 [Timestamp('2009-11-15 09:00:00'), 'yellow']
# 1 [Timestamp('2009-11-15 10:00:00'), 'yellow']
# 2 [Timestamp('2009-11-15 11:00:00'), 'green']
# 3 [Timestamp('2009-11-15 12:00:00'), 'green']
# 4 [Timestamp('2009-11-15 13:00:00'), 'green']
# 5 [Timestamp('2009-11-15 14:00:00'), 'green']

# %%
df_tweets_0_1000 = pd.DataFrame()

for count, item in enumerate(times_and_colors, start=0):
    if count > 1000:
        break
    
    if count % 100 == 0:
        print(count)
    
    try:
        weather_dict,weather,unix_time = get_weather_from_dt(item)
        df_tweets_0_1000 = df_tweets_0_1000.append(weather_dict,ignore_index=True)
    except:
        print(f'did pass on {count}')

df_tweets_0_1000.to_csv('df_tweets_0_1000.csv',index=False)
# Out:
# 0
# did pass on 91
# 100
# 200
# did pass on 209
# did pass on 210
# 300
# 400
# did pass on 437
# 500
# did pass on 582
# 600
# did pass on 655
# 700
# 800
# 900
# 1000

# %%
df_tweets_1000_2000 = pd.DataFrame()

for count, item in enumerate(times_and_colors, start=0):
    if count > 1000:
        if count > 2000:
            break

        if count % 100 == 0:
            print(count)

        try:
            weather_dict,weather,unix_time = get_weather_from_dt(item)
            df_tweets_1000_2000 = df_tweets_1000_2000.append(weather_dict,ignore_index=True)
        except:
            print(f'did pass on {count}')

df_tweets_1000_2000.to_csv('df_tweets_1000_2000.csv',index=False)
# Out:
# 1100
# 1200
# did pass on 1236
# did pass on 1238
# 1300
# 1400
# did pass on 1440
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000

# %%
df_tweets_1000_2000.head()
# Out:
#     color  precipIntensity  precipProbability        summary  temperature  \
# 0  yellow              0.0                0.0  Partly Cloudy        47.62
# 1  yellow              0.0                0.0  Partly Cloudy        50.06
# 2   green              0.0                0.0  Partly Cloudy        52.58
# 3   green              0.0                0.0  Partly Cloudy        54.09
# 4   green              0.0                0.0  Partly Cloudy        55.15
#
#             timestamp  visibility  windSpeed
# 0 2009-11-15 09:00:00       6.216       4.62
# 1 2009-11-15 10:00:00       6.216       8.16
# 2 2009-11-15 11:00:00       6.216      10.14
# 3 2009-11-15 12:00:00       6.216      10.22
# 4 2009-11-15 13:00:00       6.216      10.80

# %%
#currently

# %%
demo = pd.read_csv('df_tweets_0_1000.csv')

# %%
demo
# Out:
#     color  precipIntensity  precipProbability        summary  temperature  \
# 0  yellow              0.0                0.0  Partly Cloudy        47.62
# 1  yellow              0.0                0.0  Partly Cloudy        50.06
# 2   green              0.0                0.0  Partly Cloudy        52.58
# 3   green              0.0                0.0  Partly Cloudy        54.09
# 4   green              0.0                0.0  Partly Cloudy        55.15
# 5   green              0.0                0.0  Partly Cloudy        55.39
# 6   green              0.0                0.0  Partly Cloudy        68.59
#
#              timestamp  visibility  windSpeed
# 0  2009-11-15 09:00:00       6.216       4.62
# 1  2009-11-15 10:00:00       6.216       8.16
# 2  2009-11-15 11:00:00       6.216      10.14
# 3  2009-11-15 12:00:00       6.216      10.22
# 4  2009-11-15 13:00:00       6.216      10.80
# 5  2009-11-15 14:00:00       6.216       9.34
# 6  2011-10-04 15:00:00       6.206      10.40

# %%
df_tweets_0_1000
# Out:
#     color  precipIntensity  precipProbability        summary  temperature  \
# 0  yellow              0.0                0.0  Partly Cloudy        47.62
# 1  yellow              0.0                0.0  Partly Cloudy        50.06
# 2   green              0.0                0.0  Partly Cloudy        52.58
# 3   green              0.0                0.0  Partly Cloudy        54.09
# 4   green              0.0                0.0  Partly Cloudy        55.15
# 5   green              0.0                0.0  Partly Cloudy        55.39
# 6   green              0.0                0.0  Partly Cloudy        55.39
#
#             timestamp  visibility  windSpeed
# 0 2009-11-15 09:00:00       6.216       4.62
# 1 2009-11-15 10:00:00       6.216       8.16
# 2 2009-11-15 11:00:00       6.216      10.14
# 3 2009-11-15 12:00:00       6.216      10.22
# 4 2009-11-15 13:00:00       6.216      10.80
# 5 2009-11-15 14:00:00       6.216       9.34
# 6 2009-11-15 14:00:00       6.216       9.34

# %%
df_tweets = df_tweets.append(this_dict,ignore_index=True)

# %%
#df_tweets

# %%
this_dict = dict(x=5)

# %%
dark_sky_key = '1428dbd5b7306e4a03b3568d92f660f2' #DarkSky

with open('my_dark_sky_key.pkl', 'wb') as handle:
    pickle.dump(dark_sky_key, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
## Functions

# %%
with open('my_dark_sky_key.pkl', 'rb') as handle:
    dark_sky_key = pickle.load(handle)
    
lat_num,lng_num = 52.213268, 0.123658
lat,lng = str(lat_num),str(lng_num)
    
def get_weather_from_dt(line):
    this_timestamp, color = line
    
    # make url
    unix_time = str(int(time.mktime(this_timestamp.timetuple())))
    url = f'https://api.darksky.net/forecast/{dark_sky_key}/{lat},{lng},{unix_time}'
    
    # get weather from timestamp
    r = requests.get(url)
    weather = r.json()
    
    # parse response
    currently = weather['currently']

    weather_dict = dict(
                        timestamp = this_timestamp,
                        color = color,
                        summary = currently['summary'],
                        precipIntensity = currently['precipIntensity'],
                        precipProbability = currently['precipProbability'],
                        temperature = currently['temperature'],
                        windSpeed = currently['windSpeed'],
                        visibility = currently['visibility'])
    
    return weather_dict,weather,unix_time

# %%
def get_flag_color(dt):
    idx = 0
    this_dt = df['datetime'].iloc[idx]
    while dt > this_dt:
        idx += 1
        this_dt = df['datetime'].iloc[idx]
    last_dt = df['datetime'].iloc[idx - 1]
    color = df['color'].iloc[idx - 1]
    
    next_time = df['datetime'].iloc[idx]
    
    time_from_prev = dt - last_dt
    time_until_next = next_time - dt
    
    return last_dt, color, time_until_next, time_from_prev

# %%
pd.read_csv('df.csv')
# Out:
#      color            timestamp  precipIntensity  precipProbability  \
# 0    green  2012-11-07 07:00:00           0.0000               0.00
# 1    green  2012-11-08 07:00:00           0.0000               0.00
# 2    green  2012-11-09 07:00:00           0.0000               0.00
# 3    green  2012-11-10 07:00:00           0.0161               0.83
# 4    green  2012-11-11 07:00:00           0.0000               0.00
# 5    green  2012-11-12 07:00:00           0.0000               0.00
# 6    green  2012-11-13 07:00:00           0.0000               0.00
# 7    green  2012-11-14 07:00:00           0.0000               0.00
# 8   yellow  2012-11-15 07:00:00           0.0000               0.00
# 9    green  2012-11-16 07:00:00           0.0000               0.00
# 10   green  2012-11-17 07:00:00           0.0000               0.00
# 3      Light Rain        46.99        3.37          185       1.40
# 4           Clear        34.42        4.50          238       2.86
# 5   Partly Cloudy        41.38        5.00          184       4.32
# 6   Partly Cloudy        49.43        6.13          202       7.03
# 7        Overcast        51.29        5.32          153       3.14
# 8           Foggy        41.83        0.21           47       0.40
# 9        Overcast        42.66        4.58          180       3.84
# 10  Mostly Cloudy        52.02        3.36          184       6.18
# 11          Clear        33.14        4.94          253       3.16
# 12  Partly Cloudy        39.84        6.22          155       5.35
# 13     Light Rain        51.68        5.24          163      10.37
# 14  Mostly Cloudy        49.21        4.71          143       4.50
# 15  Partly Cloudy        48.40        6.22          164      11.31
# 16          Clear        41.70        6.21          208       5.44
# 17          Clear        33.43        3.18           95       0.98
# 18  Mostly Cloudy        46.56        6.21          238      17.50
# 19  Mostly Cloudy        46.97        6.22          148       5.82
# 20  Mostly Cloudy        45.91        5.41          352       5.67
# 21  Mostly Cloudy        40.37        6.22          340       8.86
# 22  Partly Cloudy        35.40        6.22          321       7.55
# 23          Clear        28.89        6.21          259       2.18
# 24  Partly Cloudy        30.39        5.32          232       3.41
# 25          Clear        28.07        6.21          265       5.06
# 26        Drizzle        42.19        5.71          232       6.42
# 27          Clear        36.20        6.22          260       6.81
# 28  Mostly Cloudy        33.85        4.92          355       3.29
# 29          Clear        25.65        5.89          247       2.16
# ..            ...          ...         ...          ...        ...
# 41  Mostly Cloudy        42.50        6.05          304       5.60
# 42          Foggy        38.84        0.84          134       4.87
# 43     Light Rain        42.62        5.32          129      12.11
# 44  Partly Cloudy        44.48        5.96          218       6.18
# 45        Drizzle        44.67        5.57          144       8.34
# 46  Partly Cloudy        54.51        6.21          228      12.67
# 47     Light Rain        45.43        5.47          124       4.19
# 48  Partly Cloudy        44.71        6.22          168       6.57
# 49          Clear        39.59        6.21          211       6.91
# 50          Clear        41.57        6.21          207       3.18
# 51        Drizzle        41.47        5.32          152       7.75
# 52  Mostly Cloudy        52.03        6.21          182      17.20
# 53  Partly Cloudy        40.45        6.22          218      14.32
# 54  Mostly Cloudy        50.77        6.22          195      14.09
# 55          Clear        39.15        6.21          267       3.97
# 56  Mostly Cloudy        39.12        6.21          251       2.88
# 57  Partly Cloudy        48.00        5.20          256       6.60
# 58       Overcast        49.46        6.21          251       6.92
# 59  Mostly Cloudy        46.72        4.73          211       3.61
# 60          Foggy        40.12        0.90          250       3.51
# 61  Mostly Cloudy        44.82        5.89          192       6.84
# 62  Partly Cloudy        46.66        6.22          203       6.54
# 63  Mostly Cloudy        45.06        5.50          353       3.46
# 64          Foggy        33.20        0.42          267       3.33
# 65       Overcast        37.00        3.45          289       2.12
# 66  Partly Cloudy        33.91        5.57           94       4.58
# 67       Overcast        31.45        6.21            3       4.39
# 68  Mostly Cloudy        30.36        2.67          187       2.01
# 69  Partly Cloudy        30.66        5.55          351       3.44
# 70          Foggy        24.36        0.21           90       0.10
#
# [71 rows x 9 columns]
